# %%
# Went thru manually and just saved each page of records as an html
# Collect page on one performance
import urllib
import requests
from bs4 import BeautifulSoup, NavigableString, Tag
import re
from datetime import datetime
import pandas as pd

import os

# %%
# Create a BeautifulSoup object

# Madera to Nevada 224
# Orange 681
# Placer to San Benito 707
# San Bernandino to San Diego 796
# San Francisco to Santa Clara 733
# Santa Cruz to Trinity 340

# First series of things to see how this all works
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_alameda_fresno.html", encoding = 'utf-8'), "html.parser")

# %%
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("Alameda_fresno")
len(articles)
# Out:
# Alameda_fresno
# 146

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_glenn_madera.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("Glenn_Madera")
len(articles)
# Out:
# Glenn_Madera
# 400

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_marin_nevada.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("Marin_Nevada")
len(articles)
# Out:
# Marin_Nevada
# 91

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_orange_sanfrancisco.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("orange_San Francisco")
len(articles)
# Out:
# orange_San Francisco
# 311

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_sanjoaquin_solano.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("sanjoaquin_solano")
len(articles)
# Out:
# sanjoaquin_solano
# 203

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_sonoma_yuba.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("sonoma_yuba")
len(articles)
# Out:
# sonoma_yuba
# 146

# %%
# Should have 1297 rows.

# %%
# Let's look at a random one
firstBigTag = soup.find_all('article')[100]
# Get name
name = firstBigTag.li.text
name
# Get license type
license_type = firstBigTag.li.find_next('li').find_next('li').text

# Get city name and other geo factors like county and zip
city_code = firstBigTag.find_all('span')
city = city_code[1].text

# Did this to see what we have
city_code
# Out:
# [<span id="lic100">CLN 2084</span>,
#  <span id="city100">EL CERRITO</span>,
#  <span id="city100">California</span>]

# %%
geo_stuff = firstBigTag.find_all('strong')
county = geo_stuff[7].nextSibling
zipcode = geo_stuff[8].nextSibling

# %%
zipcode
# Out:
# ' 90744'

# %%
geo_stuff
# Out:
# [<strong>License Number:</strong>,
#  <strong>License Type: </strong>,
#  <strong>License Status:</strong>,
#  <strong>Expiration Date:</strong>,
#  <strong>Secondary Status:</strong>,
#  <strong>City:</strong>,
#  <strong>State:</strong>,
#  <strong>County:</strong>,
#  <strong>Zip:</strong>]

# %%
# Will this work for other entries? (Test to see how iteration might work)
nextATag = soup.find_all('article')[101] # Just changed the index
nextATag.li.text
nextATag.li.find_next('li').find_next('li').text
next_code = nextATag.find_all('span')
next_code[1].text
geo_stuff_next = nextATag.find_all('strong')
geo_stuff_next[7].nextSibling
geo_stuff_next[8].nextSibling

# Yep seems to work!
# Out:
# ' 95973'

# %%
# make sure it is seeing all the files:
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".html"):
        print(filename)

# %%
# Put this into a big loop
name = []
license_type = []
city =[]
zipcode = []
county = []
i = 0
# Give it the base directory
directory_address = '/Users/whitneyreiner/Desktop/clinics/clinics_counties'
directory = os.fsencode(directory_address)

# Tell it to work thru the directory
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".html"):
        soup = BeautifulSoup(open(directory_address+'/'+filename, encoding = 'utf-8'), "html.parser")
        articles = soup.find_all('article')
        while i < len(articles): # This way we'll hopefully avoid an Index Error, but we have the try statement down there just in case
            firstBigTag = soup.find_all('article')[i] # This will go thru all of our entries
            # Get name
            try:
                name_temp = firstBigTag.li.text # Get name
                name.append(name_temp)
                # Get license type
                license_type_temp = firstBigTag.li.find_next('li').find_next('li').text
                license_type.append(license_type_temp)
                # Get city name and other geo factors like county and zip
                city_code = firstBigTag.find_all('span')
                city_temp = city_code[1].text
                city.append(city_temp)
                geo_stuff = firstBigTag.find_all('strong')
                county_temp = geo_stuff[7].nextSibling
                county.append(county_temp)
                zip_temp = geo_stuff[8].nextSibling
                zipcode.append(zip_temp)
            except IndexError: # In case something happens where we try to index something that doesn't exit
                continue
            i += 1 # Increase our counter
        clinics = pd.DataFrame({'name': name, # Make our data frame
                           'license_type': license_type,
                           'city': city,
                           'county': county,
                           'zip': zipcode})
clinics
# Out:
#                                                   name  \
# 0                  ALTA BATES SUMMIT PERINATAL CENTER
# 1                         AMADOR COUNTY PUBLIC HEALTH
# 2              AMPLA HEALTH ARBUCKLE MEDICAL & DENTAL
# 3     AMPLA HEALTH CHICO MEDICAL, PEDIATRICS & DENTAL
# 4                         AMPLA HEALTH COLUSA MEDICAL
# 5                        AMPLA HEALTH GRIDLEY MEDICAL
# 6                        AMPLA HEALTH MAGALIA MEDICAL
# 7              AMPLA HEALTH OROVILLE MEDICAL & DENTAL
# 8            ARIA COMMUNITY HEALTH CENTER - RIVERDALE
# 9                           ASIAN HEALTH SERVICES INC
# 10                              AXIS COMMUNITY HEALTH
# 11                              AXIS COMMUNITY HEALTH
# 12                              AXIS COMMUNITY HEALTH
# 13                                 BAY SURGERY CENTER
# 14                 BERKELEY HIGH SCHOOL HEALTH CENTER
# 15                             BERKELEY MENTAL HEALTH
# 16                      BERKELEY PUBLIC HEALTH CLINIC
# 17          BERKELEY TECHNOLOGY ACADEMY HEALTH CENTER
# 18                       BRENTWOOD SURGERY CENTER LLC
# 19   CALIFORNIA COLON & RECTAL CANCER SCREENING CEN...
# 20                              CALIFORNIA EYE CLINIC
# 21               CALIFORNIA STATE UNIVERSITY EAST BAY
# 22               CALIFORNIA STATE UNIVERSITY EAST BAY
# 23                       CANYON PINOLE SURGERY CENTER
# 24                CENTRAL CALIFORNIA ENDOSCOPY CENTER
# 25                                       CHEST CLINIC
# 26                                 CLINICA ALTA VISTA
# 27                      COMPREHENSIVE PAIN MANAGEMENT
# 28     COUNTY OF ALAMEDA HEALTH CARE FOR THE HOMELESS
# 29   COUNTY OF ALAMEDA HEALTH CARE FOR THE HOMELESS...
# ..                                                 ...
# 116                         SKYWAY SURGERY CENTER LLC
# 117  STUDENT HEALTH SERVICE CLINIC, CALIFORNIA STAT...
# 118      STUDENT HEALTH SERVICE, CA STATE UNIV, CHICO
# 119                            SURGERY CENTER FREMONT
# 120                  SUTTER AMADOR SURGERY CENTER LLC
# 121                                      TECHNICLINIC
# 122                  THE E.N.T. FACIAL SURGERY CENTER
# 123                  THE SURGERY CENTER OF ALTA BATES
# 124                 THE TRESANTI SURGICAL CENTER, LLC
# 125                    TIBURCIO VASQUEZ HEALTH CENTER
# 126     TIBURCIO VASQUEZ HEALTH CENTER - SILVA CAMPUS
# 127                TIBURCIO VASQUEZ HEALTH CENTER INC
# 128                TIBURCIO VASQUEZ HEALTH CENTER INC
# 129  TIBURCIO VASQUEZ HEALTH CENTER INC FIREHOUSE C...
# 130  TIBURCIO VASQUEZ HEALTH CENTER INC TENNYSON HI...
# 131                               TIGER HEALTH CLINIC
# 132                            TRI-CITY HEALTH CENTER
# 133                 UNITED INDIAN HEALTH SERVICES INC
# 134  UNITED INDIAN HEALTH SERVICES INC SMITH RIVER ...
# 135      UNITED INDIAN HEALTH SERVICES-KLAMATH CLINIC
# 136          UROLOGY ASSOCIATES OF CENTRAL CALIFORNIA
# 137                        VISION CARE SURGERY CENTER
# 138                 WALNUT CREEK ENDOSCOPY CENTER LLC
# 139              WASHINGTON OUTPATIENT SURGERY CENTER
# 140                        WEBSTER SURGERY CENTER, LP
# 141                     WEST BERKELEY FAMILY PRACTICE
# 142                         WEST COUNTY HEALTH CENTER
# 143               WEST FRESNO COMMUNITY HEALTH CENTER
# 144                 WEST SHAW COMMUNITY HEALTH CENTER
# 145                         YOUTH HEART HEALTH CENTER
#
#                                 license_type           city         county  \
# 0                       License Type: Clinic        OAKLAND        ALAMEDA
# 1    License Type: Clinic (Government Owned)   SUTTER CREEK         AMADOR
# 2                       License Type: Clinic       ARBUCKLE         COLUSA
# 3                       License Type: Clinic          CHICO          BUTTE
# 4                       License Type: Clinic         COLUSA         COLUSA
# 5                       License Type: Clinic        GRIDLEY          BUTTE
# 6                       License Type: Clinic        MAGALIA          BUTTE
# 7                       License Type: Clinic       OROVILLE          BUTTE
# 8                       License Type: Clinic      RIVERDALE         FRESNO
# 9                       License Type: Clinic        OAKLAND        ALAMEDA
# 10                      License Type: Clinic      LIVERMORE        ALAMEDA
# 11                      License Type: Clinic     PLEASANTON        ALAMEDA
# 12                      License Type: Clinic     PLEASANTON        ALAMEDA
# 13                      License Type: Clinic        OAKLAND        ALAMEDA
# 14   License Type: Clinic (Government Owned)       BERKELEY        ALAMEDA
# 15   License Type: Clinic (Government Owned)       BERKELEY        ALAMEDA
# 16   License Type: Clinic (Government Owned)       BERKELEY        ALAMEDA
# 17   License Type: Clinic (Government Owned)       BERKELEY        ALAMEDA
# 18                      License Type: Clinic      BRENTWOOD   CONTRA COSTA
# 19                      License Type: Clinic         FRESNO         FRESNO
# 20                      License Type: Clinic        ANTIOCH   CONTRA COSTA
# 21   License Type: Clinic (Government Owned)        HAYWARD        ALAMEDA
# 22   License Type: Clinic (Government Owned)        CONCORD   CONTRA COSTA
# 23                      License Type: Clinic         PINOLE   CONTRA COSTA
# 24                      License Type: Clinic         FRESNO         FRESNO
# 25   License Type: Clinic (Government Owned)         FRESNO         FRESNO
# 26                      License Type: Clinic        OAKLAND        ALAMEDA
# 27                      License Type: Clinic         FRESNO         FRESNO
# 28   License Type: Clinic (Government Owned)    SAN LEANDRO        ALAMEDA
# 29   License Type: Clinic (Government Owned)        OAKLAND        ALAMEDA
# ..                                       ...            ...            ...
# 116                     License Type: Clinic          CHICO          BUTTE
# 117  License Type: Clinic (Government Owned)         FRESNO         FRESNO
# 118  License Type: Clinic (Government Owned)          CHICO          BUTTE
# 119                     License Type: Clinic        FREMONT        ALAMEDA
# 120                     License Type: Clinic        JACKSON         AMADOR
# 121                     License Type: Clinic        OAKLAND        ALAMEDA
# 122                     License Type: Clinic         FRESNO         FRESNO
# 123                     License Type: Clinic        OAKLAND        ALAMEDA
# 124                     License Type: Clinic      SAN RAMON   CONTRA COSTA
# 125                     License Type: Clinic        HAYWARD        ALAMEDA
# 126                     License Type: Clinic        HAYWARD        ALAMEDA
# 127                     License Type: Clinic    SAN LEANDRO        ALAMEDA
# 128                     License Type: Clinic     UNION CITY        ALAMEDA
# 129                     License Type: Clinic        HAYWARD        ALAMEDA
# 130                     License Type: Clinic        HAYWARD        ALAMEDA
# 131                     License Type: Clinic        OAKLAND        ALAMEDA
# 132                     License Type: Clinic        FREMONT        ALAMEDA
# 133                     License Type: Clinic  CRESCENT CITY      DEL NORTE
# 134                     License Type: Clinic    SMITH RIVER      DEL NORTE
# 135                     License Type: Clinic        KLAMATH      DEL NORTE
# 136                     License Type: Clinic         FRESNO         FRESNO
# 137                     License Type: Clinic         FRESNO         FRESNO
# 138                     License Type: Clinic   WALNUT CREEK   CONTRA COSTA
# 139                     License Type: Clinic        FREMONT        ALAMEDA
# 140                     License Type: Clinic        OAKLAND        ALAMEDA
# 141                     License Type: Clinic       BERKELEY        ALAMEDA
# 142  License Type: Clinic (Government Owned)      SAN PABLO   CONTRA COSTA
# 143                     License Type: Clinic         FRESNO         FRESNO
# 144                     License Type: Clinic         FRESNO         FRESNO
# 145                     License Type: Clinic        OAKLAND        ALAMEDA
#
#         zip
# 0     94609
# 1     95685
# 2     95912
# 3     95926
# 4     95932
# 5     95948
# 6     95954
# 7     95966
# 8     93656
# 9     94607
# 10    94550
# 11    94588
# 12    94566
# 13    94609
# 14    94704
# 15    94704
# 16    94710
# 17    94703
# 18    94513
# 19    93720
# 20    94531
# 21    94542
# 22    94521
# 23    94564
# 24    93720
# 25    93721
# 26    94601
# 27    93720
# 28    94577
# 29    94601
# ..      ...
# 116   95928
# 117   93740
# 118   95929
# 119   94538
# 120   95642
# 121   94611
# 122   93720
# 123   94609
# 124   94583
# 125   94541
# 126   94544
# 127   94578
# 128   94587
# 129   94544
# 130   94544
# 131   94601
# 132   94538
# 133   95531
# 134   95567
# 135   95548
# 136   93720
# 137   93721
# 138   94598
# 139   94538
# 140   94612
# 141   94710
# 142   94806
# 143   93706
# 144   93711
# 145   94606
#
# [146 rows x 5 columns]

# %%
clinics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
# name            400 non-null object
# license_type    400 non-null object
# city            400 non-null object
# county          400 non-null object
# zip             400 non-null object
# dtypes: object(5)
# memory usage: 15.7+ KB
