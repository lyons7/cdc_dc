# %%
# Went thru manually and just saved each page of records as an html
# Collect page on one performance
import urllib
import requests
from bs4 import BeautifulSoup, NavigableString, Tag
import re
from datetime import datetime
import pandas as pd

import os

# %%
# Create a BeautifulSoup object

# Madera to Nevada 224
# Orange 681
# Placer to San Benito 707
# San Bernandino to San Diego 796
# San Francisco to Santa Clara 733
# Santa Cruz to Trinity 340

# First series of things to see how this all works
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_alameda_fresno.html", encoding = 'utf-8'), "html.parser")

# %%
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("Alameda_fresno")
len(articles)
# Out:
# Alameda_fresno
# 146

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_glenn_madera.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("Glenn_Madera")
len(articles)
# Out:
# Glenn_Madera
# 400

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_marin_nevada.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("Marin_Nevada")
len(articles)
# Out:
# Marin_Nevada
# 91

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_orange_sanfrancisco.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("orange_San Francisco")
len(articles)
# Out:
# orange_San Francisco
# 311

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_sanjoaquin_solano.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("sanjoaquin_solano")
len(articles)
# Out:
# sanjoaquin_solano
# 203

# %%
# Read in the html
soup = BeautifulSoup(open("/Users/whitneyreiner/Desktop/clinics/clinics_counties/clinic_sonoma_yuba.html", encoding = 'utf-8'), "html.parser")
# Can be illustrative to look at data directly (not really in this case)
# soup

# Thanks to Abhilash, we know 'article' is where all of our info is so let's take a note of all of those tags
articles = soup.find_all('article')

# We'll access each entry by its index, so just want to see how big this thing is to know what I can/can't index
print("sonoma_yuba")
len(articles)
# Out:
# sonoma_yuba
# 146

# %%
# Should have 1297 rows.

# %%
# Let's look at a random one
firstBigTag = soup.find_all('article')[100]
# Get name
name = firstBigTag.li.text
name
# Get license type
license_type = firstBigTag.li.find_next('li').find_next('li').text

# Get city name and other geo factors like county and zip
city_code = firstBigTag.find_all('span')
city = city_code[1].text

# Did this to see what we have
city_code
# Out:
# [<span id="lic100">CLN 2084</span>,
#  <span id="city100">EL CERRITO</span>,
#  <span id="city100">California</span>]

# %%
geo_stuff = firstBigTag.find_all('strong')
county = geo_stuff[7].nextSibling
zipcode = geo_stuff[8].nextSibling

# %%
zipcode
# Out:
# ' 90744'

# %%
geo_stuff
# Out:
# [<strong>License Number:</strong>,
#  <strong>License Type: </strong>,
#  <strong>License Status:</strong>,
#  <strong>Expiration Date:</strong>,
#  <strong>Secondary Status:</strong>,
#  <strong>City:</strong>,
#  <strong>State:</strong>,
#  <strong>County:</strong>,
#  <strong>Zip:</strong>]

# %%
# Will this work for other entries? (Test to see how iteration might work)
nextATag = soup.find_all('article')[101] # Just changed the index
nextATag.li.text
nextATag.li.find_next('li').find_next('li').text
next_code = nextATag.find_all('span')
next_code[1].text
geo_stuff_next = nextATag.find_all('strong')
geo_stuff_next[7].nextSibling
geo_stuff_next[8].nextSibling

# Yep seems to work!
# Out:
# ' 95973'

# %%
# Put this into a big loop
name = []
license_type = []
city =[]
zip = []
county = []
i = 0

# %%
# How many of these do we have? We want to just increase that index, that will get us all the entries we want
# Or if we get a nothing... just keep going
# Go through to each htm file
# Give it the base directory
directory_address = '/Users/whitneyreiner/Desktop/clinics/clinics_counties'
directory = os.fsencode(directory_address)

# %%
# make sure it is seeing all the files:
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".html"):
        print(filename)

# %%
# Tell it to work thru the directory
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".html"):
        soup = BeautifulSoup(open(directory_address+'/'+filename, encoding = 'utf-8'), "html.parser")
        articles = soup.find_all('article')
        while i < len(articles): # This way we'll hopefully avoid an Index Error, but we have the try statement down there just in case
            firstBigTag = soup.find_all('article')[i] # This will go thru all of our entries
            # Get name
            try:
                name_temp = firstBigTag.li.text # Get name
                name.append(name_temp)
                # Get license type
                license_type_temp = firstBigTag.li.find_next('li').find_next('li').text
                license_type.append(license_type_temp)
                # Get city name and other geo factors like county and zip
                city_code = firstBigTag.find_all('span')
                city_temp = city_code[1].text
                city.append(city_temp)
                geo_stuff = firstBigTag.find_all('strong')
                county_temp = geo_stuff[7].nextSibling
                county.append(county_temp)
                zip_temp = geo_stuff[8].nextSibling
                zipcode.append(zip_temp)
            except IndexError: # In case something happens where we try to index something that doesn't exit
                continue
            i += 1 # Increase our counter
        clinics = pd.DataFrame({'name': name, # Make our data frame
                           'license_type': license_type,
                           'city': city,
                           'county': county,
                           'zip': zipcode})
clinics
# Out:
#                                                   name  \
# 0                              ABJ SURGERY CENTER INC
# 1                             ADVANCED SURGERY CENTER
# 2                             ADVANCED SURGERY CENTER
# 3               AMBULATORY SURGERY CENTER OF STOCKTON
# 4                       ANDERSON FAMILY HEALTH CENTER
# 5                               APOGEE SURGERY CENTER
# 6                               BASCOM SURGERY CENTER
# 7                      BAY AREA DENTAL SURGERY CENTER
# 8                                BURNEY HEALTH CENTER
# 9                          BUTTE VALLEY HEALTH CENTER
# 10                           CAL POLY HEALTH SERVICES
# 11                              CAMPUS SURGERY CENTER
# 12                            CAPITOLA SURGERY CENTER
# 13    CENTER FOR SPECIALIZED SURGERY OF SANTA BARBARA
# 14                       CENTRAL COAST SURGERY CENTER
# 15                         CHC PALISADE WOMENS HEALTH
# 16                       CHC TEMPLETON WOMEN'S HEALTH
# 17         CHINESE HOSPITAL DALY CITY HEALTH SERVICES
# 18           CHINESE HOSPITAL GELLERT HEALTH SERVICES
# 19                         COASTAL SURGICAL INSTITUTE
# 20                           COMMUNITY HEALTH CENTERS
# 21                           COMMUNITY HEALTH CENTERS
# 22                   COMMUNITY HEALTH CENTERS  LOMPOC
# 23              COMMUNITY HEALTH CENTERS - NEW CUYAMA
# 24             COMMUNITY HEALTH CENTERS ARROYO GRANDE
# 25                COMMUNITY HEALTH CENTERS ATASCADERO
# 26                   COMMUNITY HEALTH CENTERS CAMBRIA
# 27                      COMMUNITY HEALTH CENTERS CASA
# 28                      COMMUNITY HEALTH CENTERS CASA
# 29                      COMMUNITY HEALTH CENTERS CASA
# ..                                                 ...
# 370  TWIN TOWERS CORRECTIONAL FACILITY TOWER I DENT...
# 371  TWIN TOWERS CORRECTIONAL FACILITY TOWER I MAIN...
# 372  TWIN TOWERS CORRECTIONAL FACILITY TOWER II DEN...
# 373  TWIN TOWERS CORRECTIONAL FACILITY TOWER II MAI...
# 374              UCLA SCHOOL OF NURSING HEALTH CENTER
# 375  USC - EISNER FAMILY MEDICINE CENTER AT CALIFOR...
# 376                          VALENCIA SURGICAL CENTER
# 377                           VALLEY COMMUNITY CLINIC
# 378                       VALLEY COMMUNITY HEALTHCARE
# 379                    VALLEY DIGESTIVE HEALTH CENTER
# 380                           VALLEY ENDOSCOPY CENTER
# 381  VALLEY PHYSICIANS SURGERY CENTER AT NORTHRIDGE...
# 382                              VAN NUYS JAIL CLINIC
# 383         VENICE FAMILY CLINIC-LEVINE FAMILY HEALTH
# 384             VIA CARE COMMUNITY HEALTH CENTER, INC
# 385                                        WEE DENTAL
# 386                 WESLEY HEALTH CENTER (BELLFLOWER)
# 387                    WESLEY HEALTH CENTER (LYNWOOD)
# 388                    WESLEY HEALTH CENTERS (DOWNEY)
# 389                     WESLEY HEALTH CENTERS (FEDDE)
# 390          WESLEY HEALTH CENTERS (HACIENDA HEIGHTS)
# 391     WESLEY HEALTH CENTERS (LYNWOOD MIDDLE SCHOOL)
# 392                  WESLEY HEALTH CENTERS (PATHWAYS)
# 393                   WESLEY HEALTH CENTERS (VERMONT)
# 394                  WESLEY HEALTH CENTERS (WHITTIER)
# 395          WESLEY HEALTH CENTERS AT ANDREW ESCAJEDA
# 396                         WEST DELANO DENTAL CENTER
# 397                     WESTSIDE FAMILY HEALTH CENTER
# 398                      WESTSIDE SURGICAL CENTER LLC
# 399                       WILMINGTON COMMUNITY CLINIC
#
#                                 license_type              city        county  \
# 0                       License Type: Clinic         SAN MATEO   LOS ANGELES
# 1                       License Type: Clinic          SAN JOSE   LOS ANGELES
# 2                       License Type: Clinic          SAN JOSE   LOS ANGELES
# 3                       License Type: Clinic          STOCKTON   LOS ANGELES
# 4                       License Type: Clinic          ANDERSON   LOS ANGELES
# 5                       License Type: Clinic           REDDING   LOS ANGELES
# 6                       License Type: Clinic          CAMPBELL   LOS ANGELES
# 7                       License Type: Clinic          MILPITAS   LOS ANGELES
# 8                       License Type: Clinic            BURNEY   LOS ANGELES
# 9                       License Type: Clinic            DORRIS   LOS ANGELES
# 10   License Type: Clinic (Government Owned)   SAN LUIS OBISPO   LOS ANGELES
# 11                      License Type: Clinic         DALY CITY   LOS ANGELES
# 12                      License Type: Clinic          CAPITOLA   LOS ANGELES
# 13                      License Type: Clinic     SANTA BARBARA   LOS ANGELES
# 14                      License Type: Clinic           FREEDOM   LOS ANGELES
# 15                      License Type: Clinic       SANTA MARIA   LOS ANGELES
# 16                      License Type: Clinic         TEMPLETON   LOS ANGELES
# 17                      License Type: Clinic         DALY CITY   LOS ANGELES
# 18                      License Type: Clinic         DALY CITY   LOS ANGELES
# 19                      License Type: Clinic       PISMO BEACH   LOS ANGELES
# 20                      License Type: Clinic       SANTA MARIA   LOS ANGELES
# 21                      License Type: Clinic       SANTA MARIA   LOS ANGELES
# 22                      License Type: Clinic            LOMPOC   LOS ANGELES
# 23                      License Type: Clinic        NEW CUYAMA   LOS ANGELES
# 24                      License Type: Clinic     ARROYO GRANDE   LOS ANGELES
# 25                      License Type: Clinic        ATASCADERO   LOS ANGELES
# 26                      License Type: Clinic           CAMBRIA   LOS ANGELES
# 27                      License Type: Clinic   SAN LUIS OBISPO   LOS ANGELES
# 28                      License Type: Clinic   SAN LUIS OBISPO   LOS ANGELES
# 29                      License Type: Clinic   SAN LUIS OBISPO   LOS ANGELES
# ..                                       ...               ...           ...
# 370  License Type: Clinic (Government Owned)       LOS ANGELES   LOS ANGELES
# 371  License Type: Clinic (Government Owned)       LOS ANGELES   LOS ANGELES
# 372  License Type: Clinic (Government Owned)       LOS ANGELES   LOS ANGELES
# 373  License Type: Clinic (Government Owned)       LOS ANGELES   LOS ANGELES
# 374  License Type: Clinic (Government Owned)       LOS ANGELES   LOS ANGELES
# 375                     License Type: Clinic       LOS ANGELES   LOS ANGELES
# 376                     License Type: Clinic     SANTA CLARITA   LOS ANGELES
# 377                     License Type: Clinic     GRANADA HILLS   LOS ANGELES
# 378                     License Type: Clinic       NORTH HILLS   LOS ANGELES
# 379                     License Type: Clinic           ARCADIA   LOS ANGELES
# 380                     License Type: Clinic         EL CENTRO   LOS ANGELES
# 381                     License Type: Clinic        NORTHRIDGE   LOS ANGELES
# 382  License Type: Clinic (Government Owned)          VAN NUYS   LOS ANGELES
# 383                     License Type: Clinic            VENICE   LOS ANGELES
# 384                     License Type: Clinic       LOS ANGELES   LOS ANGELES
# 385                     License Type: Clinic           HANFORD   LOS ANGELES
# 386                     License Type: Clinic        BELLFLOWER   LOS ANGELES
# 387                     License Type: Clinic           LYNWOOD   LOS ANGELES
# 388                     License Type: Clinic            DOWNEY   LOS ANGELES
# 389                     License Type: Clinic  HAWAIIAN GARDENS   LOS ANGELES
# 390                     License Type: Clinic  HACIENDA HEIGHTS   LOS ANGELES
# 391                     License Type: Clinic           LYNWOOD   LOS ANGELES
# 392                     License Type: Clinic       LOS ANGELES   LOS ANGELES
# 393                     License Type: Clinic       LOS ANGELES   LOS ANGELES
# 394                     License Type: Clinic          WHITTIER   LOS ANGELES
# 395                     License Type: Clinic          PASADENA   LOS ANGELES
# 396                     License Type: Clinic            DELANO   LOS ANGELES
# 397                     License Type: Clinic      SANTA MONICA   LOS ANGELES
# 398                     License Type: Clinic       BAKERSFIELD   LOS ANGELES
# 399                     License Type: Clinic        WILMINGTON   LOS ANGELES
#
#         zip
# 0     90744
# 1     90744
# 2     90744
# 3     90744
# 4     90744
# 5     90744
# 6     90744
# 7     90744
# 8     90744
# 9     90744
# 10    90744
# 11    90744
# 12    90744
# 13    90744
# 14    90744
# 15    90744
# 16    90744
# 17    90744
# 18    90744
# 19    90744
# 20    90744
# 21    90744
# 22    90744
# 23    90744
# 24    90744
# 25    90744
# 26    90744
# 27    90744
# 28    90744
# 29    90744
# ..      ...
# 370   90744
# 371   90744
# 372   90744
# 373   90744
# 374   90744
# 375   90744
# 376   90744
# 377   90744
# 378   90744
# 379   90744
# 380   90744
# 381   90744
# 382   90744
# 383   90744
# 384   90744
# 385   90744
# 386   90744
# 387   90744
# 388   90744
# 389   90744
# 390   90744
# 391   90744
# 392   90744
# 393   90744
# 394   90744
# 395   90744
# 396   90744
# 397   90744
# 398   90744
# 399   90744
#
# [400 rows x 5 columns]

# %%
clinics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
# name            400 non-null object
# license_type    400 non-null object
# city            400 non-null object
# county          400 non-null object
# zip             400 non-null object
# dtypes: object(5)
# memory usage: 15.7+ KB
